# %%
from scipy.ndimage import gaussian_filter,median_filter,uniform_filter
import sys 
sys.path.append('../Functions')
from application import applyfilter
from application import applygauss
from application import apply
from histogram_streching import histogram_stretching
from histogram_streching import histogram_stretching2

# %%
# application of different preprocessing methods(filter) on the different datasets


# application Uniform filter size 3X3

#N2DH-GOWT1
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Mean/N2DH-GOWT1/3x3/',S =3)

#N2DL-HeLa
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Mean/N2DL-HeLa/3x3/',S =3)

#NIH3T3
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Mean/NIH3T3/3x3/',S=3)


# application Median filter size 3X3

#N2DH-GOWT1
applyfilter(median_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Median/N2DH-GOWT1/3x3/',S =3)

#N2DL-HeLa
applyfilter(median_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Median/N2DL-HeLa/3x3/',S =3)

#NIH3T3
applyfilter(median_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Median/NIH3T3/3x3/',S=3)


# application Uniform filter size 5X5

#N2DH-GOWT1
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Mean/N2DH-GOWT1/5x5/',S =5)

#N2DL-HeLa
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Mean/N2DL-HeLa/5x5/',S =5)

#NIH3T3
applyfilter(uniform_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Mean/NIH3T3/5x5/',S=5)


# application Median filter size 5X5

#N2DH-GOWT1
applyfilter(median_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Median/N2DH-GOWT1/5x5/',S =5)

#N2DL-HeLa
applyfilter(median_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Median/N2DL-HeLa/5x5/',S =5)

#NIH3T3
applyfilter(median_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Median/NIH3T3/5x5/',S=5)


# application Gausian filter with sigma = 1, 2, 3 on the different Datasets


# application Gausian filter sigma = 1

#N2DH-GOWT1
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Gauss/N2DH-GOWT1/1/',S =1)

#N2DL-HeLa
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Gauss/N2DL-HeLa/1/',S =1 )

#NIH3T3
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Gauss/NIH3T3/1/',S =1 )

# application Gausian filter sigma = 2

#N2DH-GOWT1
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Gauss/N2DH-GOWT1/2/',S =2)

#N2DL-HeLa
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Gauss/N2DL-HeLa/2/',S =2 )

#NIH3T3
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Gauss/NIH3T3/2/',S =2 )

# application Gausian filter sigma = 3

#N2DH-GOWT1
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Gauss/N2DH-GOWT1/3/',S =3)

#N2DL-HeLa
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Gauss/N2DL-HeLa/3/',S =3 )

#NIH3T3
applygauss(gaussian_filter,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Gauss/NIH3T3/3/',S =3 )

# %%
# application of histogram streching as a preprocessing method on different datasets

#N2DH-GOWT1
apply(histogram_stretching,'../BilderDaten/BilderDaten/N2DH-GOWT1/img/','../Ergebnisse/Histogramm_stretching/N2DH-GOWT1/')

#N2DL-HeLa
apply(histogram_stretching2,'../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/Histogramm_stretching/N2DL-HeLa/')

#NIH3T3
apply(histogram_stretching,'../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/Histogramm_stretching/NIH/')

# %%
# application of histogram streching as an additional preprocessing method on pictures, that already have been preprocessed with different filter

# apllication histogram streching on Gausian filter sigma = 1, 2, 3

#N2DH-GOWT1

apply(histogram_stretching,'../Ergebnisse/Gauss/N2DH-GOWT1/1/','../Ergebnisse/Gauss+Histogrammstreching/N2DH-GOWT1/1/')

apply(histogram_stretching,'../Ergebnisse/Gauss/N2DH-GOWT1/2/','../Ergebnisse/Gauss+Histogrammstreching/N2DH-GOWT1/2/')

apply(histogram_stretching,'../Ergebnisse/Gauss/N2DH-GOWT1/3/','../Ergebnisse/Gauss+Histogrammstreching/N2DH-GOWT1/3/')

#N2DL-HeLa

apply(histogram_stretching2,'../Ergebnisse/Gauss/N2DL-HeLa/1/','../Ergebnisse/Gauss+Histogrammstreching/N2DL-HeLa/1/')

apply(histogram_stretching2,'../Ergebnisse/Gauss/N2DL-HeLa/2/','../Ergebnisse/Gauss+Histogrammstreching/N2DL-HeLa/2/')

apply(histogram_stretching2,'../Ergebnisse/Gauss/N2DL-HeLa/3/','../Ergebnisse/Gauss+Histogrammstreching/N2DL-HeLa/3/')

#NIH3T3

apply(histogram_stretching,'../Ergebnisse/Gauss/NIH3T3/1/','../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/1/')

apply(histogram_stretching,'../Ergebnisse/Gauss/NIH3T3/2/','../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/2/')

apply(histogram_stretching,'../Ergebnisse/Gauss/NIH3T3/3/','../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/3/')

# application histogram streching on Uniform filter 3x3, 5x5

#N2DH-GOWT1

apply(histogram_stretching,'../Ergebnisse/Mean/N2DH-GOWT1/3x3/','../Ergebnisse/Mean+Histogrammstreching/N2DH-GOWT1/3x3/')

apply(histogram_stretching,'../Ergebnisse/Mean/N2DH-GOWT1/5x5/','../Ergebnisse/Mean+Histogrammstreching/N2DH-GOWT1/5x5/')

#N2DL-HeLa

apply(histogram_stretching2,'../Ergebnisse/Mean/N2DL-HeLa/3x3/','../Ergebnisse/Mean+Histogrammstreching/N2DL-HeLa/3x3/')

apply(histogram_stretching2,'../Ergebnisse/Mean/N2DL-HeLa/5x5/','../Ergebnisse/Mean+Histogrammstreching/N2DL-HeLa/5x5/')

#NIH3T3

apply(histogram_stretching,'../Ergebnisse/Mean/NIH3T3/3x3/','../Ergebnisse/Mean+Histogrammstreching/NIH3T3/3x3/')

apply(histogram_stretching,'../Ergebnisse/Mean/NIH3T3/5x5/','../Ergebnisse/Mean+Histogrammstreching/NIH3T3/5x5/')


# application histogram on Median filter 3x3, 5x5

#N2DH-GOWT1

apply(histogram_stretching,'../Ergebnisse/Median/N2DH-GOWT1/3x3/','../Ergebnisse/Median+Histogrammstreching/N2DH-GOWT1/3x3/')

apply(histogram_stretching,'../Ergebnisse/Median/N2DH-GOWT1/5x5/','../Ergebnisse/Median+Histogrammstreching/N2DH-GOWT1/5x5/')

#N2DL-HeLa

apply(histogram_stretching2,'../Ergebnisse/Median/N2DL-HeLa/3x3/','../Ergebnisse/Median+Histogrammstreching/N2DL-HeLa/3x3/')

apply(histogram_stretching2,'../Ergebnisse/Median/N2DL-HeLa/5x5/','../Ergebnisse/Median+Histogrammstreching/N2DL-HeLa/5x5/')

#NIH3T3

apply(histogram_stretching,'../Ergebnisse/Median/NIH3T3/3x3/','../Ergebnisse/Median+Histogrammstreching/NIH3T3/3x3/')

apply(histogram_stretching,'../Ergebnisse/Median/NIH3T3/5x5/','../Ergebnisse/Median+Histogrammstreching/NIH3T3/5x5/')
