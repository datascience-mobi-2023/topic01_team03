# %%
import sys 
sys.path.append('../Functions')
from application import applydice

# %%
#dice score otsu without preprocessing

#N2DH-GOWT1
dice1_normal = list()
applydice('../Ergebnisse/Otsu/N2DH-GOWT1/','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_normal)

#N2DL-HeLa
dice2_normal = list()
applydice('../Ergebnisse/Otsu/N2DL-HeLa/','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_normal)

#NIH3T3
dice3_normal = list()
applydice('../Ergebnisse/Otsu/NIH3T3/','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_normal)

# %%
#dice score uniformfilter

#3x3

#N2DH-GOWT1
dice1_mean3 = list()
applydice('../Ergebnisse/Mean+Otsu/N2DH-GOWT1/3x3','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_mean3)

#N2DL-HeLa
dice2_mean3 = list()
applydice('../Ergebnisse/Mean+Otsu/N2DL-HeLa/3x3','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_mean3)

#NIH3T3
dice3_mean3 = list()
applydice('../Ergebnisse/Mean+Otsu/NIH3T3/3x3','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_mean3)


#5x5

#N2DH-GOWT1
dice1_mean5 = list()
applydice('../Ergebnisse/Mean+Otsu/N2DH-GOWT1/5x5','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_mean5)

#N2DL-HeLa
dice2_mean5 = list()
applydice('../Ergebnisse/Mean+Otsu/N2DL-HeLa/5x5','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_mean5)

#NIH3T3
dice3_mean5 = list()
applydice('../Ergebnisse/Mean+Otsu/NIH3T3/5x5','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_mean5)

# %%
#dice score  medianfilter

#3x3

#N2DH-GOWT1
dice1_median3 = list()
applydice('../Ergebnisse/Median+Otsu/N2DH-GOWT1/3x3','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_median3)

#N2DL-HeLa
dice2_median3 = list()
applydice('../Ergebnisse/Median+Otsu/N2DL-HeLa/3x3','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_median3)

#NIH3T3
dice3_median3 = list()
applydice('../Ergebnisse/Median+Otsu/NIH3T3/3x3','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_median3)


#5x5

#N2DH-GOWT1
dice1_median5 = list()
applydice('../Ergebnisse/Median+Otsu/N2DH-GOWT1/5x5','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_median5)

#N2DL-HeLa
dice2_median5 = list()
applydice('../Ergebnisse/Median+Otsu/N2DL-HeLa/5x5','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_median5)

#NIH3T3
dice3_median5 = list()
applydice('../Ergebnisse/Median+Otsu/NIH3T3/5x5','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_median5)

# %%
#dice score mit gaussfilter

#1

#N2DH-GOWT1
dice1_gauss1 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DH-GOWT1/1','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_gauss1)

#N2DL-HeLa
dice2_gauss1 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DL-HeLa/1','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_gauss1)

#NIH3T3
dice3_gauss1 = list()
applydice('../Ergebnisse/Gauss+Otsu/NIH3T3/1','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_gauss1)


#2

#N2DH-GOWT1
dice1_gauss2 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DH-GOWT1/2','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_gauss2)

#N2DL-HeLa
dice2_gauss2 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DL-HeLa/2','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_gauss2)

#NIH3T3
dice3_gauss2 = list()
applydice('../Ergebnisse/Gauss+Otsu/NIH3T3/2','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_gauss2)


#3

#N2DH-GOWT1
dice1_gauss3 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DH-GOWT1/3','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_gauss3)

#N2DL-HeLa
dice2_gauss3 = list()
applydice('../Ergebnisse/Gauss+Otsu/N2DL-HeLa/3','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_gauss3)

#NIH3T3
dice3_gauss3 = list()
applydice('../Ergebnisse/Gauss+Otsu/NIH3T3/3','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_gauss3)

# %%
#dice score local thresholding

#N2DH-GOWT1
dice1_local = list()
applydice('../Ergebnisse/local_thresholding/N2DH-GOWT1/','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_local)

#N2DL-HeLa
dice2_local = list()
applydice('../Ergebnisse/local_thresholding/N2DL-HeLa/','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_local)

#NIH3T3
dice3_local = list()
applydice('../Ergebnisse/local_thresholding/NIH3T3/','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_local)

# %%
#dice score mit histogramm stretching

#N2DH-GOWT1
dice1_histogramm = list()
applydice('../Ergebnisse/Histogramm+Otsu/N2DH-GOWT1/','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_histogramm)

#N2DL-HeLa
dice2_histogramm = list()
applydice('../Ergebnisse/Histogramm+Otsu/N2DL-HeLa/','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_histogramm)

#NIH3T3
dice3_histogramm = list()
applydice('../Ergebnisse/Histogramm+Otsu/NIH3T3/','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_histogramm)

# %%
#dice score two level otsu

#N2DH-GOWT1
dice1_twolevel = list()
applydice('../Ergebnisse/twolevel_otsu/N2DH-GOWT1/','../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/',dice1_twolevel)

#N2DL-HeLa
dice2_twolevel = list()
applydice('../Ergebnisse/twolevel_otsu/N2DL-HeLa/','../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/',dice2_twolevel)

#NIH3T3
dice3_twolevel = list()
applydice('../Ergebnisse/twolevel_otsu/NIH3T3/','../BilderDaten/BilderDaten/NIH3T3/gt_binarized/',dice3_twolevel)
# Out:
# [0.8983564376831055, 0.9431095123291016, 0.8150901794433594, 0.8831081390380859, 0.9399557113647461, 0.9010858535766602]

# %%
#dice score histogramm streching + Gausian Filter

#1

#N2DH-GOWT1
dice1_histo_gauss1 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DH-GOWT1/1/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_gauss1)

#N2DL-HeLa
dice2_histo_gauss1 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DL-HeLa/1/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_gauss1)

#NIH3T3
dice3_histo_gauss1 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/1/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_gauss1)

#2

#N2DH-GOWT1
dice1_histo_gauss2 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DH-GOWT1/2/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_gauss2)

#N2DL-HeLa
dice2_histo_gauss2 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DL-HeLa/2/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_gauss2)

#NIH3T3
dice3_histo_gauss2 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/2/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_gauss2)

#3

#N2DH-GOWT1
dice1_histo_gauss3 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DH-GOWT1/3/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_gauss3)

#N2DL-HeLa
dice2_histo_gauss3 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/N2DL-HeLa/3/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_gauss3)

#NIH3T3
dice3_histo_gauss3 = list()
applydice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/3/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_gauss3)

# %%
# dice score histogramm streching + Uniform filter

#3x3

#N2DH-GOWT1
dice1_histo_uniform3 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/N2DH-GOWT1/3x3/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_uniform3)

#N2DL-HeLa
dice2_histo_uniform3 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/N2DL-HeLa/3x3/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_uniform3)

#NIH3T3
dice3_histo_uniform3 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/NIH3T3/3x3/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_uniform3)

#5x5

#N2DH-GOWT1
dice1_histo_uniform5 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/N2DH-GOWT1/5x5/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_uniform5)

#N2DL-HeLa
dice2_histo_uniform5 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/N2DL-HeLa/5x5/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_uniform5)

#NIH3T3
dice3_histo_uniform5 = list()
applydice('../Ergebnisse/Mean+Histo+Otsu/NIH3T3/5x5/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_uniform5)

# %%
# dice score histogramm streching + Median filter

#3x3

#N2DH-GOWT1
dice1_histo_median3 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/N2DH-GOWT1/3x3/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_median3)

#N2DL-HeLa
dice2_histo_median3 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/N2DL-HeLa/3x3/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_median3)

#NIH3T3
dice3_histo_median3 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/NIH3T3/3x3/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_median3)

#5x5

#N2DH-GOWT1
dice1_histo_median5 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/N2DH-GOWT1/5x5/', '../BilderDaten/BilderDaten/N2DH-GOWT1/gt_binarized/', dice1_histo_median5)

#N2DL-HeLa
dice2_histo_median5 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/N2DL-HeLa/5x5/', '../BilderDaten/BilderDaten/N2DL-HeLa/gt_binarized/', dice2_histo_median5)

#NIH3T3
dice3_histo_median5 = list()
applydice('../Ergebnisse/Median+Histo+Otsu/NIH3T3/5x5/', '../BilderDaten/BilderDaten/NIH3T3/gt_binarized/', dice3_histo_median5)
