# %%
import numpy as np
import matplotlib
import scipy.ndimage
from skimage import io
from matplotlib import pyplot as plt

img = io.imread('C:/Users/selig/mambaforge/envs/compmeth2022/Data/N2DH-GOWT1/img/t01.tif')
plt.imshow( img,'gray' )

# %%
img = io.imread("C:/Users/selig/mambaforge/envs/compmeth2022/Data/N2DH-GOWT1/gt/man_seg01.tif")
plt.imshow( img,'gray' )
