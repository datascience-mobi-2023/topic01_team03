# %%
from skimage import io
def slice(path):
    img = io.imread(path)
    img2 = img[:,:,0]
    io.imsave(path,img2)

# %%
#normal

slice('../BilderDaten/BilderDaten/NIH3T3/img/dna-28.png')

slice('../BilderDaten/BilderDaten/NIH3T3/img/dna-29.png')

slice('../BilderDaten/BilderDaten/NIH3T3/img/dna-37.png')

#Gauss

slice('../Ergebnisse/Gauss/NIH3T3/1/dna-28.png')

slice('../Ergebnisse/Gauss/NIH3T3/1/dna-29.png')

slice('../Ergebnisse/Gauss/NIH3T3/1/dna-37.png')

slice('../Ergebnisse/Gauss/NIH3T3/2/dna-28.png')

slice('../Ergebnisse/Gauss/NIH3T3/2/dna-29.png')

slice('../Ergebnisse/Gauss/NIH3T3/2/dna-37.png')

slice('../Ergebnisse/Gauss/NIH3T3/3/dna-28.png')

slice('../Ergebnisse/Gauss/NIH3T3/3/dna-29.png')

slice('../Ergebnisse/Gauss/NIH3T3/3/dna-37.png')

#Gauss+Histo+Otsu

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/1/dna-28.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/1/dna-29.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/1/dna-37.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/2/dna-28.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/2/dna-29.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/2/dna-37.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/3/dna-28.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/3/dna-29.png')

slice('../Ergebnisse/Gauss+Histo+Otsu/NIH3T3/3/dna-37.png')

# Gaus Histo

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/1/dna-28.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/1/dna-29.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/1/dna-37.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/2/dna-28.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/2/dna-29.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/2/dna-37.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/3/dna-28.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/3/dna-29.png')

slice('../Ergebnisse/Gauss+Histogrammstreching/NIH3T3/3/dna-37.png')

#Histogrammstreching

slice('../Ergebnisse/Histogramm_stretching/NIH3T3/dna-28.png')

slice('../Ergebnisse/Histogramm_stretching/NIH3T3/dna-29.png')

slice('../Ergebnisse/Histogramm_stretching/NIH3T3/dna-37.png')

#Histo+Otsu

slice('../Ergebnisse/Histogramm+Otsu/NIH3T3/dna-28.png')

slice('../Ergebnisse/Histogramm+Otsu/NIH3T3/dna-29.png')

slice('../Ergebnisse/Histogramm+Otsu/NIH3T3/dna-37.png')

#Mean

slice('../Ergebnisse/Mean/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Mean/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Mean/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Mean/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Mean/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Mean/NIH3T3/5x5/dna-37.png')

#Mean+Otsu

slice('../Ergebnisse/Mean+Otsu/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Mean+Otsu/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Mean+Otsu/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Mean+Otsu/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Mean+Otsu/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Mean+Otsu/NIH3T3/5x5/dna-37.png')

#mean+histo

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Mean+Histogrammstreching/NIH3T3/5x5/dna-37.png')

#Median

slice('../Ergebnisse/Median/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Median/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Median/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Median/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Median/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Median/NIH3T3/5x5/dna-37.png')

#Median+Otsu

slice('../Ergebnisse/Median+Otsu/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Median+Otsu/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Median+Otsu/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Median+Otsu/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Median+Otsu/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Median+Otsu/NIH3T3/5x5/dna-37.png')

#Median+histo

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/3x3/dna-28.png')

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/3x3/dna-29.png')

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/3x3/dna-37.png')

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/5x5/dna-28.png')

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/5x5/dna-29.png')

slice('../Ergebnisse/Median+Histogrammstreching/NIH3T3/5x5/dna-37.png')

#Otsu

slice('../Ergebnisse/Otsu/NIH3T3/dna-28.png')

slice('../Ergebnisse/Otsu/NIH3T3/dna-29.png')

slice('../Ergebnisse/Otsu/NIH3T3/dna-37.png')
