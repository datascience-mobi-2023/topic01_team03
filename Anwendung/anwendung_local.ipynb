# %%
import numpy as np
import os
from skimage import io
def local_thresholding_vek1(img, window_size):
    half_window = window_size // 2
    top_rows = img[:half_window, :][::-1, :]
    bottom_rows = img[-half_window:, :][::-1, :]
    imgM = np.concatenate((top_rows, img, bottom_rows), axis=0)
    
    left_cols = imgM[:, :half_window][:, ::-1]
    right_cols = imgM[:, -half_window:][:, ::-1]
    imgM = np.concatenate((left_cols, imgM, right_cols), axis=1)
    imgT = imgM.copy()
    start_index = (half_window, half_window)
    end_index = (imgM.shape[0]-half_window,imgM.shape[1]-half_window)

    for p in np.ndindex(imgM.shape):
        if end_index[0] > p[0] >= start_index[0] and end_index[1] > p[1] >= start_index[1]:
            
            window = imgM[p[0] - half_window : p[0] + half_window + 1, p[1] - half_window : p[1] + half_window + 1]
             
            rvl = window.ravel()
            ran = round(max(rvl) - min(rvl))
            counts, bins = np.histogram(rvl, bins=ran)
            
            sum_back = np.cumsum(counts)[:-1]
            sum_obj = sum(counts)-sum_back
            mean_back = np.cumsum(bins[:-2]*counts[:-1])/sum_back
            mean_obj = (sum(bins[:-2]*counts[:-1])-np.cumsum(bins[:-2]*counts[:-1]))/sum_obj
            w0_list = sum_back/sum(counts)
            w1_list = 1 - w0_list

            #calculate background and foreground variance
            var_back_list = list()
            var_obj_list = list()
            for i in range (0,len(mean_back)):
                var_back = sum(counts[:i]*(bins[:i]-mean_back[i])**2)/sum_back[i]
                var_back_list.append(var_back)
                var_obj = sum(counts[i:]*(bins[i:-1]-mean_obj[i])**2)/sum_obj[i]
                var_obj_list.append(var_obj)
        
   
        
            wcv_list = (w0_list * var_back_list) + (w1_list * var_obj_list)
            THRESH = bins[np.argmin(wcv_list)]
            
 
            if imgM[p] < THRESH:
                imgT[p] = 0
            else:
                imgT[p] = 255

    return imgT

import numpy as np
def local_thresholding_vek2(img, window_size):
    half_window = window_size // 2
    top_rows = img[:half_window, :][::-1, :]
    bottom_rows = img[-half_window:, :][::-1, :]
    imgM = np.concatenate((top_rows, img, bottom_rows), axis=0)
    
    left_cols = imgM[:, :half_window][:, ::-1]
    right_cols = imgM[:, -half_window:][:, ::-1]
    imgM = np.concatenate((left_cols, imgM, right_cols), axis=1)
    imgT = imgM.copy()
    start_index = (half_window, half_window)
    end_index = (imgM.shape[0]-half_window,imgM.shape[1]-half_window)

    for p in np.ndindex(imgM.shape):
        if end_index[0] > p[0] >= start_index[0] and end_index[1] > p[1] >= start_index[1]:
            
            window = imgM[p[0] - half_window : p[0] + half_window + 1, p[1] - half_window : p[1] + half_window + 1]
             
            rvl = window.ravel()
            ran = round(max(rvl) - min(rvl))
            counts, bins = np.histogram(rvl, bins=ran)
            
            sum_back = np.cumsum(counts)[:-1]
            sum_obj = sum(counts)-sum_back
            mean_back = np.cumsum(bins[:-2]*counts[:-1])/sum_back
            mean_obj = (sum(bins[:-2]*counts[:-1])-np.cumsum(bins[:-2]*counts[:-1]))/sum_obj
            w0_list = sum_back/sum(counts)
            w1_list = 1 - w0_list

            #calculate background and foreground variance
            var_back_list = list()
            var_obj_list = list()
            for i in range (0,len(mean_back)):
                var_back = sum(counts[:i]*(bins[:i]-mean_back[i])**2)/sum_back[i]
                var_back_list.append(var_back)
                var_obj = sum(counts[i:]*(bins[i:-1]-mean_obj[i])**2)/sum_obj[i]
                var_obj_list.append(var_obj)
        
   
        
            wcv_list = (w0_list * var_back_list) + (w1_list * var_obj_list)
            THRESH = bins[np.argmin(wcv_list)]
            
 
            if imgM[p] < THRESH:
                imgT[p] = 0
            else:
                imgT[p] = 65535

    return imgT
def anwendunglocal(input_path,result_path,S):
    files = os.listdir(input_path)
    for file in files:
        file_path = os.path.join(input_path,file)
        result_file_path = os.path.join(result_path,file)
        result = local_thresholding_vek1(io.imread(file_path),window_size=S)
        io.imsave(result_file_path,result)
        
def anwendunglocal2(input_path,result_path,S):
    files = os.listdir(input_path)
    for file in files:
        file_path = os.path.join(input_path,file)
        result_file_path = os.path.join(result_path,file)
        result = local_thresholding_vek2(io.imread(file_path),window_size=S)
        io.imsave(result_file_path,result)

# %%
#NIH3T3
anwendunglocal('../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/local_thresholding/NIH3T3/',S =401)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #NIH3T3
# ----> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> anwendunglocal('../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/local_thresholding/NIH3T3/',S =401)
#
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 2 in anwendunglocal(input_path, result_path, S)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=108'>109</a> file_path = os.path.join(input_path,file)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=109'>110</a> result_file_path = os.path.join(result_path,file)
# --> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=110'>111</a> result = local_thresholding_vek1(io.imread(file_path),window_size=S)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=111'>112</a> io.imsave(result_file_path,result)
#
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 2 in local_thresholding_vek1(img, window_size)
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> window = imgM[p[0] - half_window : p[0] + half_window + 1, p[1] - half_window : p[1] + half_window + 1]
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> rvl = window.ravel()
# ---> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> ran = round(max(rvl) - min(rvl))
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> counts, bins = np.histogram(rvl, bins=ran)
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a> sum_back = np.cumsum(counts)[:-1]
#
# KeyboardInterrupt:

# %%
#N2DL-HeLa
anwendunglocal2('../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/local_thresholding/N2DL-HeLa/',S =401)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> #N2DL-HeLa
# ----> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> anwendunglocal2('../BilderDaten/BilderDaten/N2DL-HeLa/img/','../Ergebnisse/local_thresholding/N2DL-HeLa/',S =401)
#       <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> #NIH3T3
#       <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> anwendunglocal('../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/local_thresholding/NIH3T3/',S =401)
#
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 3 in anwendunglocal2(input_path, result_path, S)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=116'>117</a> file_path = os.path.join(input_path,file)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=117'>118</a> result_file_path = os.path.join(result_path,file)
# --> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=118'>119</a> result = local_thresholding_vek2(io.imread(file_path),window_size=S)
#     <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=119'>120</a> io.imsave(result_file_path,result)
#
# /Users/anna-lena/compmeth2022/topic01_team03 /Anwendung/anwendung_local.ipynb Zelle 3 in local_thresholding_vek2(img, window_size)
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=86'>87</a> var_obj_list = list()
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=87'>88</a> for i in range (0,len(mean_back)):
# ---> <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=88'>89</a>     var_back = sum(counts[:i]*(bins[:i]-mean_back[i])**2)/sum_back[i]
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=89'>90</a>     var_back_list.append(var_back)
#      <a href='vscode-notebook-cell:/Users/anna-lena/compmeth2022/topic01_team03%20/Anwendung/anwendung_local.ipynb#W1sZmlsZQ%3D%3D?line=90'>91</a>     var_obj = sum(counts[i:]*(bins[i:-1]-mean_obj[i])**2)/sum_obj[i]
#
# KeyboardInterrupt:

# %%
#NIH3T3
anwendunglocal('../BilderDaten/BilderDaten/NIH3T3/img/','../Ergebnisse/local_thresholding/NIH3T3/',S =401)
