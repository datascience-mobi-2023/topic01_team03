# %%
from scipy.ndimage import gaussian_filter
from skimage import io
import matplotlib.pyplot as plt

img1 = io.imread("C:/Users/selig/topic01_team03/BilderDaten/BilderDaten/N2DH-GOWT1/img/t01.tif")

# Zahl (hier gerade 3) nach img ist variabel -> ausprobieren, was am besten, je höher desto unschärfer
plt.imshow(gaussian_filter(img1, 3), "gray")
